# %%
from IPython.display import Audio, Image

# %%
Image("outputs\\generated-waves.jpg")

# %%
Image("outputs\\test-audio.jpg")

# %%
Audio(data = "inputs\\test-audio.wav", autoplay = False)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Image("outputs\\test-audio-filtered.jpg")

# %%
Audio(data = "outputs\\test-audio-filtered.wav", autoplay = False)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
